# %%
import librosa as lr
import IPython.display as ipd
import matplotlib.pyplot as plt
import tensorflow 
import numpy as np
from glob import glob
import cv2
from matplotlib.backends.backend_agg import FigureCanvasAgg as FigureCanvas
# %matplotlib inline
import librosa.display
from IPython.display import Audio
import pandas as pd
import os
from sklearn.model_selection import train_test_split
import splitfolders
import skimage.io

# %%
filename = '/content/174276-7-6-0.wav'
hop_length=320
window_type='hann'
nfft=1024

# %%
filename='/content/174276-7-6-0.wav'
plt.figure(figsize=(14,5))
data,sample_rate=librosa.load(filename)
librosa.display.waveplot(data,sr=sample_rate)
ipd.Audio(filename)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
y, sr = librosa.load('/content/174276-7-6-0.wav', sr=32000)

# %%
mel_bins = 64
fmin = 0
fmax= None
Mel_spectrogram = librosa.feature.melspectrogram(y=y, sr=sr, n_fft=n_fft, hop_length=hop_length, win_length=n_fft, window=window_type, n_mels = mel_bins, power=2.0)


librosa.display.specshow(Mel_spectrogram, sr=sr, x_axis='time', y_axis='mel',hop_length=hop_length)
plt.colorbar(format='%+2.0f dB')
plt.title('Dog Bark')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-b734744fbad9> in <module>
#       2 fmin = 0
#       3 fmax= None
# ----> 4 Mel_spectrogram = librosa.feature.melspectrogram(y=y, sr=sr, n_fft=n_fft, hop_length=hop_length, win_length=n_fft, window=window_type, n_mels = mel_bins, power=2.0)
#       5
#       6
#
# NameError: name 'n_fft' is not defined

# %%
mel_spectrogram_db = librosa.power_to_db(Mel_spectrogram, ref=np.max)
print("The shape of Log Mel spectrogram is: ", mel_spectrogram_db.shape)
librosa.display.specshow(mel_spectrogram_db, sr=sr, x_axis='time', y_axis='mel',hop_length=hop_length)
plt.colorbar(format='%+2.0f dB')
plt.title('Dog Bark Mel Spectrogram')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-69a2319d5a51> in <module>
# ----> 1 mel_spectrogram_db = librosa.power_to_db(Mel_spectrogram, ref=np.max)
#       2 print("The shape of Log Mel spectrogram is: ", mel_spectrogram_db.shape)
#       3 librosa.display.specshow(mel_spectrogram_db, sr=sr, x_axis='time', y_axis='mel',hop_length=hop_length)
#       4 plt.colorbar(format='%+2.0f dB')
#       5 plt.title('Dog Bark Mel Spectrogram')
#
# NameError: name 'Mel_spectrogram' is not defined
